# %%
#!pip install uszipcode
#pip install pyqt5==5.12.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes = True)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

from uszipcode import SearchEngine

import time
import datetime
import dateutil.parser
#import dateutil
#from dateutil.parser import *

# %%
daily = pd.read_csv("beat19-collab-data\\versions\\2020-06-01\\daily-data.csv")
enrollment = pd.read_csv("beat19-collab-data\\versions\\2020-06-01\\enrollment-data.csv")

# %%
print(daily.info())
print("*********************************************")
print(enrollment.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39032 entries, 0 to 39031
# Data columns (total 81 columns):
# _id                                  39032 non-null object
# rel_date                             39032 non-null int64
# date                                 39032 non-null object
# updated_at                           39032 non-null object
# version                              39032 non-null int64
# ble_prompt                           39032 non-null bool
# ble_travel_prompt                    39032 non-null bool
# ble_travel_outside                   14395 non-null float64
# ble_travel_bike                      4649 non-null float64
# ble_travel_bus                       4649 non-null float64
# ble_travel_car                       4649 non-null float64
# ble_travel_train                     4649 non-null float64
# ble_travel_taxi                      4649 non-null float64
# ble_travel_walk                      4649 non-null float64
# ble_travel_time                      3209 non-null float64
# ble_travel_interactions              13809 non-null float64
# ble_sip                              14163 non-null float64
# ble_household_sick                   14382 non-null float64
# ble_physically_feeling               14352 non-null float64
# ble_stress                           14341 non-null float64
# ble_concerned                        14363 non-null float64
# ble_care_prompt                      39032 non-null bool
# ble_care_clinic                      485 non-null float64
# ble_care_hospitalized                487 non-null float64
# ble_care_telemedicine                486 non-null float64
# ble_care_flu_prompt                  39032 non-null bool
# ble_care_flu_result                  85 non-null float64
# ble_care_covid_prompt                39032 non-null bool
# ble_care_covid_result                225 non-null float64
# ble_care_covid_date                  121 non-null object
# ble_care_covid_rel_date              121 non-null float64
# ble_care_covid_recovered             0 non-null float64
# med_prompt                           39032 non-null bool
# med_text                             597 non-null object
# med_rx_prompt                        39032 non-null bool
# med_rx_text                          302 non-null object
# med_supp_prompt                      39032 non-null bool
# med_supp_text                        753 non-null object
# med_other                            527 non-null object
# sym_prompt                           39032 non-null bool
# sym_ent_prompt                       39032 non-null bool
# sym_ent_headache_severity            3350 non-null float64
# sym_ent_smell_severity               3344 non-null float64
# sym_ent_sore_severity                3350 non-null float64
# sym_ent_runny_severity               3350 non-null float64
# sym_ent_stuffy_severity              3350 non-null float64
# sym_ent_itchy_severity               3350 non-null float64
# sym_ent_watery_severity              3350 non-null float64
# sym_ent_dizzy_severity               1058 non-null float64
# sym_ent_dizzy_frequency              1058 non-null float64
# sym_ent_other                        945 non-null object
# sym_git_prompt                       39032 non-null bool
# sym_git_nausea_frequency             986 non-null float64
# sym_git_nausea_severity              986 non-null float64
# sym_git_vomiting_frequency           986 non-null float64
# sym_git_vomiting_severity            986 non-null float64
# sym_git_diarrhea_frequency           986 non-null float64
# sym_git_other                        297 non-null object
# sym_resp_prompt                      39032 non-null bool
# sym_resp_wheezing_severity           1810 non-null float64
# sym_resp_sneezing_severity           1810 non-null float64
# sym_resp_coughing_severity           1810 non-null float64
# sym_resp_wet                         1385 non-null float64
# sym_resp_bloody                      1465 non-null float64
# sym_resp_dyspnea_severity            1810 non-null float64
# sym_resp_other                       543 non-null object
# sym_fever_prompt                     39032 non-null bool
# sym_fever_temp_prompt                39032 non-null bool
# sym_fever_temp                       218 non-null float64
# sym_fever_chills_frequency           1897 non-null float64
# sym_fever_chills_severity            1897 non-null float64
# sym_fever_aches_severity             1898 non-null float64
# sym_fever_fatigue_severity           1898 non-null float64
# sym_fever_sleeping_severity          895 non-null float64
# sym_fever_other                      532 non-null object
# change_ace_inhibitor                 39032 non-null int64
# change_arb                           39032 non-null int64
# change_thiazide                      39032 non-null int64
# change_potassium_sparing_diuretic    39032 non-null int64
# change_beta_blocker                  39032 non-null int64
# change_hydroxychloroquine            39032 non-null int64
# dtypes: bool(14), float64(47), int64(8), object(12)
# memory usage: 20.5+ MB
# None
# *********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2905 entries, 0 to 2904
# Data columns (total 73 columns):
# _id                           2905 non-null object
# date                          2905 non-null object
# age                           2905 non-null object
# gender                        2905 non-null object
# ethnicity                     2846 non-null float64
# race                          2905 non-null object
# shelter_in_place              2664 non-null float64
# household_size                2858 non-null object
# state                         2841 non-null object
# zip_postcode                  2905 non-null object
# country                       2905 non-null object
# exposure                      1913 non-null float64
# hcw_setting                   2905 non-null int64
# work_setting_clinic           2905 non-null int64
# work_setting_hospital         2905 non-null int64
# work_setting_nursinghome      2905 non-null int64
# work_setting_seniorcare       2905 non-null int64
# work_setting_other            2905 non-null int64
# BMI                           2860 non-null float64
# health_status                 2895 non-null object
# smoker                        2905 non-null object
# exercise                      2893 non-null float64
# health_prompt                 2905 non-null bool
# prescriptions                 1576 non-null object
# ace_inhibitor                 2905 non-null int64
# arb                           2905 non-null int64
# thiazide                      2905 non-null int64
# potassium_sparing_diuretic    2905 non-null int64
# beta_blocker                  2905 non-null int64
# hydroxychloroquine            2905 non-null int64
# other_condition_desc          711 non-null object
# has_resp_condition            2905 non-null int64
# has_heart_blood_condition     2905 non-null int64
# has_immune_condition          2905 non-null int64
# has_other_condition           2905 non-null int64
# asthma_condition              2905 non-null int64
# asthma_meds                   2905 non-null int64
# copd_condition                2905 non-null int64
# copd_meds                     2905 non-null int64
# emphysema_condition           2905 non-null int64
# emphysema_meds                2905 non-null int64
# lungdis_tb_condition          2905 non-null int64
# lungdis_tb_meds               2905 non-null int64
# allergies_condition           2905 non-null int64
# allergies_meds                2905 non-null int64
# hiv_aids_condition            2905 non-null int64
# hiv_aids_meds                 2905 non-null int64
# transplant_condition          2905 non-null int64
# transplant_meds               2905 non-null int64
# bleeding_condition            2905 non-null int64
# bleeding_meds                 2905 non-null int64
# bloodpressure_condition       2905 non-null int64
# bloodpressure_meds            2905 non-null int64
# heartdis_condition            2905 non-null int64
# heartdis_meds                 2905 non-null int64
# arrhythmia_condition          2905 non-null int64
# arrhythmia_meds               2905 non-null int64
# stroke_condition              2905 non-null int64
# stroke_meds                   2905 non-null int64
# alzheimers_condition          2905 non-null int64
# alzheimers_meds               2905 non-null int64
# cancer_condition              2905 non-null int64
# cancer_meds                   2905 non-null int64
# kidneydis_condition           2905 non-null int64
# kidneydis_meds                2905 non-null int64
# diabetes_condition            2905 non-null int64
# diabetes_meds                 2905 non-null int64
# arthritis_condition           2905 non-null int64
# arthritis_meds                2905 non-null int64
# liverdis_condition            2905 non-null int64
# liverdis_meds                 2905 non-null int64
# other_condition               2905 non-null int64
# other_meds                    2905 non-null int64
# dtypes: bool(1), float64(5), int64(54), object(13)
# memory usage: 1.6+ MB
# None

# %%
daily_ttl_records = len(daily)
daily_unique_ids = daily._id.nunique()

enrollment_ttl = len(enrollment)
unique_enrollment = enrollment._id.nunique()

print(f"number of records in daily df: {daily_ttl_records}" )
print(f"number of unique _ids in daily df': {daily_unique_ids}")
print()
print("*************************************************************")

print(f"number of records in enrollment df: {enrollment_ttl}" )
print(f"number of unique _ids in enrollment df': {unique_enrollment}")
print()
# Out:
# number of records in daily df: 39032
# number of unique _ids in daily df': 2081
#
# *************************************************************
# number of records in enrollment df: 2905
# number of unique _ids in enrollment df': 2905

# %% [markdown]
# **Average number of entries per participant:**

# %%
avg_time_steps = daily_ttl_records / daily_unique_ids
print(f"each unique id has an average of{avg_time_steps: .0f} records")
# Out:
# each unique id has an average of 19 records

# %% [markdown]
# **Columns with NaN values:**

# %%
cols = list(daily)
counter = 0
for i in cols:
    if daily[i].isna().any() ==True:  #daily[i] is a series
        counter += 1
        
print(f"there are {counter} out of 81 columns ({counter/len(daily.columns) * 100: .0f}%) in df daily with NaN values")
print(f"percent of column NaN values range from 60% to 100%")
# Out:
# there are 56 out of 81 columns ( 69%) in df daily with NaN values
# percent of column NaN values range from 60% to 100%

# %% [markdown]
# **NaN percent per feature:**

# %%
percent_nan = daily.isna().sum() * 100 / len(daily)
missing_values = pd.DataFrame({'column_name' : daily.columns,
                              'percent_nan' : percent_nan})
missing_values.reset_index(drop=True, inplace = True)
missing_values.sort_values(by= "percent_nan")
# Out:
#                           column_name  percent_nan
# 0                                 _id     0.000000
# 27              ble_care_covid_prompt     0.000000
# 32                         med_prompt     0.000000
# 34                      med_rx_prompt     0.000000
# 36                    med_supp_prompt     0.000000
# 39                         sym_prompt     0.000000
# 79                change_beta_blocker     0.000000
# 25                ble_care_flu_prompt     0.000000
# 51                     sym_git_prompt     0.000000
# 66                   sym_fever_prompt     0.000000
# 67              sym_fever_temp_prompt     0.000000
# 75               change_ace_inhibitor     0.000000
# 76                         change_arb     0.000000
# 77                    change_thiazide     0.000000
# 78  change_potassium_sparing_diuretic     0.000000
# 58                    sym_resp_prompt     0.000000
# 21                    ble_care_prompt     0.000000
# 40                     sym_ent_prompt     0.000000
# 80          change_hydroxychloroquine     0.000000
# 1                            rel_date     0.000000
# 2                                date     0.000000
# 3                          updated_at     0.000000
# 4                             version     0.000000
# 5                          ble_prompt     0.000000
# 6                   ble_travel_prompt     0.000000
# 7                  ble_travel_outside    63.120004
# 17                 ble_household_sick    63.153310
# 20                      ble_concerned    63.201988
# 18             ble_physically_feeling    63.230170
# 19                         ble_stress    63.258352
# 16                            ble_sip    63.714388
# 15            ble_travel_interactions    64.621336
# 9                      ble_travel_bus    88.089260
# 10                     ble_travel_car    88.089260
# 11                   ble_travel_train    88.089260
# 8                     ble_travel_bike    88.089260
# 12                    ble_travel_taxi    88.089260
# 13                    ble_travel_walk    88.089260
# 41          sym_ent_headache_severity    91.417299
# 44             sym_ent_runny_severity    91.417299
# 45            sym_ent_stuffy_severity    91.417299
# 46             sym_ent_itchy_severity    91.417299
# 47            sym_ent_watery_severity    91.417299
# 43              sym_ent_sore_severity    91.417299
# 42             sym_ent_smell_severity    91.432671
# 14                    ble_travel_time    91.778541
# 72         sym_fever_fatigue_severity    95.137323
# 71           sym_fever_aches_severity    95.137323
# 70          sym_fever_chills_severity    95.139885
# 69         sym_fever_chills_frequency    95.139885
# 61         sym_resp_coughing_severity    95.362779
# 64          sym_resp_dyspnea_severity    95.362779
# 59         sym_resp_wheezing_severity    95.362779
# 60         sym_resp_sneezing_severity    95.362779
# 63                    sym_resp_bloody    96.246669
# 62                       sym_resp_wet    96.451629
# 48             sym_ent_dizzy_severity    97.289404
# 49            sym_ent_dizzy_frequency    97.289404
# 54         sym_git_vomiting_frequency    97.473868
# 56         sym_git_diarrhea_frequency    97.473868
# 55          sym_git_vomiting_severity    97.473868
# 53            sym_git_nausea_severity    97.473868
# 52           sym_git_nausea_frequency    97.473868
# 50                      sym_ent_other    97.578910
# 73        sym_fever_sleeping_severity    97.707010
# 37                      med_supp_text    98.070814
# 33                           med_text    98.470486
# 65                     sym_resp_other    98.608834
# 74                    sym_fever_other    98.637016
# 38                          med_other    98.649826
# 23              ble_care_hospitalized    98.752306
# 24              ble_care_telemedicine    98.754868
# 22                    ble_care_clinic    98.757430
# 35                        med_rx_text    99.226276
# 57                      sym_git_other    99.239086
# 28              ble_care_covid_result    99.423550
# 68                     sym_fever_temp    99.441484
# 30            ble_care_covid_rel_date    99.689998
# 29                ble_care_covid_date    99.689998
# 26                ble_care_flu_result    99.782230
# 31           ble_care_covid_recovered   100.000000

# %%
# remove NaN columns
missing_val_dict = dict(zip(missing_values["column_name"], missing_values["percent_nan"]))

to_drop = []
for k, v in missing_val_dict.items():
    if v >= 50:
        to_drop.append(k)
        
daily.drop(columns = to_drop, inplace = True)

# %%
# impute county based off zip

search = SearchEngine(simple_zipcode=False)

counties = []
for i in enrollment.zip_postcode:
    counties.append(search.by_zipcode(i).county)

enrollment.insert(10, "county", counties )

# %%
# view records missing county info; can we fix?
missing_county = enrollment[enrollment['county'].isnull()]
num_missing = len(missing_county)
print(f"Enrollment db cannot match counties to {num_missing} zip codes that were not entered accurately. This translates into 149 total time steps.")
# Out:
# Enrollment db cannot match counties to 14 zip codes that were not entered accurately. This translates into 149 total time steps.

# %%
# pull in county by id into daily df

data = daily.merge(enrollment[['_id','state', 'county']] , how = 'outer', on = '_id')
print(data.shape)

# drop records missing county
data = data[data['county'].notna()]
print(data.shape)
# Out:
# (39856, 27)
# (39707, 27)

# %%
# change date and updated_at to type datetime
data["date"] = pd.to_datetime(data["date"])
data["updated_at"] = pd.to_datetime(data["updated_at"])

# %% [markdown]
# **Average number of entries per day per county:**

# %%
# calc average number of records per county per day
unique_counties = list(data.county.unique())
avg_visit_per_day_per_county = {}
for cnty in unique_counties:
    df = data[data["county"] == cnty ]
    ttl_dates = df["date"].count()
    unique_dates = len(list(df["date"].unique()))
    avg_daily_visits = ttl_dates / unique_dates
    avg_visit_per_day_per_county[cnty] = avg_daily_visits
    
sorted_avg_visits = sorted(avg_visit_per_day_per_county.items(), key = lambda x: x[1], reverse = True)
sorted_avg_visits
# Out:
# [('Santa Clara County', 50.04615384615385),
#  ('San Mateo County', 26.5625),
#  ('San Diego County', 16.266666666666666),
#  ('Middlesex County', 14.875),
#  ('San Francisco County', 14.661538461538461),
#  ('Durham County', 14.476923076923077),
#  ('Alameda County', 14.046153846153846),
#  ('Los Angeles County', 13.921875),
#  ('Jackson County', 12.904761904761905),
#  ('Maricopa County', 12.375),
#  ('Clark County', 11.571428571428571),
#  ('Orange County', 10.938461538461539),
#  ('Wake County', 9.738461538461538),
#  ('Montgomery County', 9.396825396825397),
#  ('King County', 9.107692307692307),
#  ('Santa Cruz County', 8.553846153846154),
#  ('Tulare County', 8.236363636363636),
#  ('Contra Costa County', 6.923076923076923),
#  ('Douglas County', 6.203125),
#  ('Harris County', 5.87037037037037),
#  ('Norfolk County', 5.73015873015873),
#  ('Suffolk County', 5.5625),
#  ('Cook County', 5.4375),
#  ('Delaware County', 5.423728813559322),
#  ('Fairfax County', 5.396825396825397),
#  ('Pinellas County', 5.298245614035087),
#  ('Monterey County', 4.803571428571429),
#  ('Riverside County', 4.328125),
#  ('Albemarle County', 4.079365079365079),
#  ('Monmouth County', 3.6440677966101696),
#  ('Snohomish County', 3.4814814814814814),
#  ('Johnson County', 3.40625),
#  ('Hamilton County', 3.377049180327869),
#  ('Denver County', 3.3125),
#  ('Spokane County', 3.19672131147541),
#  ('Jefferson County', 3.1746031746031744),
#  ('Solano County', 3.152542372881356),
#  ('St. Louis County', 3.1076923076923078),
#  ('Summit County', 3.0833333333333335),
#  ('Essex County', 3.0517241379310347),
#  ('Travis County', 3.0),
#  ('New York County', 2.9836065573770494),
#  ('Bernalillo County', 2.9655172413793105),
#  ('Yolo County', 2.7868852459016393),
#  ('Monroe County', 2.75),
#  ('Howard County', 2.7419354838709675),
#  ('Tarrant County', 2.6481481481481484),
#  ('Erie County', 2.609375),
#  ('Marin County', 2.58),
#  ('Manatee County', 2.5660377358490565),
#  ('Cumberland County', 2.5535714285714284),
#  ('Westchester County', 2.546875),
#  ("Prince George's County", 2.5384615384615383),
#  ('Lake County', 2.5283018867924527),
#  ('Dallas County', 2.5),
#  ('Williamson County', 2.4909090909090907),
#  ('Nassau County', 2.4833333333333334),
#  ('Broward County', 2.4705882352941178),
#  ('Pima County', 2.4693877551020407),
#  ('DuPage County', 2.388888888888889),
#  ('Hennepin County', 2.3728813559322033),
#  ('Hampden County', 2.3658536585365852),
#  ('Lancaster County', 2.3508771929824563),
#  ('Chittenden County', 2.35),
#  ('Escambia County', 2.3275862068965516),
#  ('Franklin County', 2.3214285714285716),
#  ('Allegheny County', 2.293103448275862),
#  ('Salt Lake County', 2.282051282051282),
#  ('Utah County', 2.2545454545454544),
#  ('Madison County', 2.1923076923076925),
#  ('Sacramento County', 2.1724137931034484),
#  ('Multnomah County', 2.1587301587301586),
#  ('Loudoun County', 2.142857142857143),
#  ('Kings County', 2.1296296296296298),
#  ('Worcester County', 2.1052631578947367),
#  ('Bexar County', 2.066666666666667),
#  ('Oakland County', 2.0),
#  ('Brunswick County', 1.9666666666666666),
#  ('St. Louis city', 1.9333333333333333),
#  ('Greene County', 1.9318181818181819),
#  ('Washington County', 1.9024390243902438),
#  ('Fairfield County', 1.8823529411764706),
#  ('Polk County', 1.8275862068965518),
#  ('Dane County', 1.8),
#  ('Baltimore County', 1.7924528301886793),
#  ('Baltimore city', 1.7857142857142858),
#  ('Santa Barbara County', 1.7692307692307692),
#  ('Sonoma County', 1.7377049180327868),
#  ('Adams County', 1.736842105263158),
#  ('DeKalb County', 1.702127659574468),
#  ('Anne Arundel County', 1.6923076923076923),
#  ('Linn County', 1.68),
#  ('Kauai County', 1.679245283018868),
#  ('Buffalo County', 1.6666666666666667),
#  ('St. Croix County', 1.6666666666666667),
#  ('Burlington County', 1.65),
#  ('Union County', 1.6440677966101696),
#  ('Dauphin County', 1.6440677966101696),
#  ('Lucas County', 1.6428571428571428),
#  ('Kanawha County', 1.6333333333333333),
#  ('Collin County', 1.6166666666666667),
#  ('Bucks County', 1.6097560975609757),
#  ('Santa Fe County', 1.6),
#  ('Cuyahoga County', 1.5964912280701755),
#  ('Washtenaw County', 1.5806451612903225),
#  ('Sarasota County', 1.5593220338983051),
#  ('Davidson County', 1.5555555555555556),
#  ('Jasper County', 1.55),
#  ('Barren County', 1.5454545454545454),
#  ('Kootenai County', 1.5423728813559323),
#  ('Palm Beach County', 1.5396825396825398),
#  ('Fulton County', 1.5245901639344261),
#  ('Tulsa County', 1.5135135135135136),
#  ('Lehigh County', 1.4833333333333334),
#  ('Camden County', 1.48),
#  ('Columbia County', 1.4782608695652173),
#  ('Albany County', 1.4615384615384615),
#  ('Arapahoe County', 1.453125),
#  ('Jefferson Parish', 1.4523809523809523),
#  ('Scott County', 1.4489795918367347),
#  ('Wayne County', 1.4333333333333333),
#  ('St. Charles County', 1.4181818181818182),
#  ('Coconino County', 1.4090909090909092),
#  ('York County', 1.3902439024390243),
#  ('Boone County', 1.3829787234042554),
#  ('Buncombe County', 1.3725490196078431),
#  ('Ocean County', 1.3620689655172413),
#  ('Logan County', 1.3571428571428572),
#  ('New Haven County', 1.3529411764705883),
#  ('Shelby County', 1.3461538461538463),
#  ('Philadelphia County', 1.3409090909090908),
#  ('Boulder County', 1.3333333333333333),
#  ('Ouachita Parish', 1.3333333333333333),
#  ('Kitsap County', 1.3333333333333333),
#  ('Lafayette County', 1.3278688524590163),
#  ('Charlotte County', 1.326086956521739),
#  ('Livingston County', 1.3157894736842106),
#  ('Ventura County', 1.3148148148148149),
#  ('El Paso County', 1.3125),
#  ('Deschutes County', 1.3),
#  ('Queens County', 1.2954545454545454),
#  ('Brevard County', 1.2916666666666667),
#  ('Waukesha County', 1.2903225806451613),
#  ('Mille Lacs County', 1.2857142857142858),
#  ('Bell County', 1.28),
#  ('Carver County', 1.2777777777777777),
#  ('Roanoke County', 1.2777777777777777),
#  ('Charleston County', 1.2758620689655173),
#  ('Barnstable County', 1.2452830188679245),
#  ('Berks County', 1.2413793103448276),
#  ('Placer County', 1.2291666666666667),
#  ('Osceola County', 1.2222222222222223),
#  ('Butler County', 1.2142857142857142),
#  ('Collier County', 1.2127659574468086),
#  ('Kalamazoo County', 1.2083333333333333),
#  ('Duval County', 1.2083333333333333),
#  ('Allen County', 1.2),
#  ('Cobb County', 1.2),
#  ('Tom Green County', 1.2),
#  ('St. Clair County', 1.2),
#  ('Macomb County', 1.2),
#  ('Grant County', 1.1914893617021276),
#  ('Mohave County', 1.1891891891891893),
#  ('District of Columbia', 1.1851851851851851),
#  ('Pinal County', 1.1785714285714286),
#  ('Miami-Dade County', 1.173913043478261),
#  ('Wright County', 1.1666666666666667),
#  ('Limestone County', 1.1636363636363636),
#  ('Winnebago County', 1.1538461538461537),
#  ('Gregg County', 1.1428571428571428),
#  ('Hillsborough County', 1.1372549019607843),
#  ('Hartford County', 1.127659574468085),
#  ('Centre County', 1.125),
#  ('Lee County', 1.1219512195121952),
#  ('Cabarrus County', 1.119047619047619),
#  ('Atlantic County', 1.1111111111111112),
#  ('Flathead County', 1.1111111111111112),
#  ('Greenville County', 1.105263157894737),
#  ('James City County', 1.1025641025641026),
#  ('Ontario County', 1.1025641025641026),
#  ('Strafford County', 1.1),
#  ('Saratoga County', 1.0952380952380953),
#  ('Denton County', 1.0909090909090908),
#  ('Cherokee County', 1.0888888888888888),
#  ('Warren County', 1.088235294117647),
#  ('Alamance County', 1.0857142857142856),
#  ('Richmond city', 1.0810810810810811),
#  ('Honolulu County', 1.0793650793650793),
#  ('Steuben County', 1.0769230769230769),
#  ('Cowlitz County', 1.0769230769230769),
#  ('Fort Bend County', 1.0769230769230769),
#  ('Volusia County', 1.0714285714285714),
#  ('Seminole County', 1.0689655172413792),
#  ('Mower County', 1.0625),
#  ('Calhoun County', 1.0606060606060606),
#  ('Charlottesville city', 1.06),
#  ('Prince William County', 1.0588235294117647),
#  ('Mecklenburg County', 1.0555555555555556),
#  ('Baldwin County', 1.0555555555555556),
#  ('Campbell County', 1.0555555555555556),
#  ('Washoe County', 1.0526315789473684),
#  ('Darlington County', 1.032258064516129),
#  ('Westmoreland County', 1.03125),
#  ('Wood County', 1.0294117647058822),
#  ('Anchorage Municipality', 1.0222222222222221),
#  ('Tompkins County', 1.0192307692307692),
#  ('McHenry County', 1.0),
#  ('Bronx County', 1.0),
#  ('Colbert County', 1.0),
#  ('Graham County', 1.0),
#  ('Archuleta County', 1.0),
#  ('Meigs County', 1.0),
#  ('San Juan Municipio', 1.0),
#  ('Nye County', 1.0),
#  ('Otsego County', 1.0),
#  ('Coffee County', 1.0),
#  ('Sarpy County', 1.0),
#  ('Hunterdon County', 1.0),
#  ('Crow Wing County', 1.0),
#  ('Currituck County', 1.0),
#  ('Caddo Parish', 1.0),
#  ('Medina County', 1.0),
#  ('Dickinson County', 1.0),
#  ('Saginaw County', 1.0),
#  ('Chisago County', 1.0),
#  ('Johnston County', 1.0),
#  ('Baxter County', 1.0),
#  ('Canyon County', 1.0),
#  ('Manitowoc County', 1.0),
#  ('Lane County', 1.0),
#  ('Nicollet County', 1.0),
#  ('Lycoming County', 1.0),
#  ('Anoka County', 1.0),
#  ('Cabell County', 1.0),
#  ('Ford County', 1.0),
#  ('Richland County', 1.0),
#  ('Pope County', 1.0),
#  ('Henry County', 1.0),
#  ('Missoula County', 1.0),
#  ('Larimer County', 1.0),
#  ('Cheyenne County', 1.0),
#  ('Ramsey County', 1.0),
#  ('Mahoning County', 1.0),
#  ('Merrick County', 1.0),
#  ('Jones County', 1.0),
#  ('Tillamook County', 1.0),
#  ('Litchfield County', 1.0),
#  ('Grays Harbor County', 1.0),
#  ('Antelope County', 1.0),
#  ('Tuolumne County', 1.0),
#  ('Floyd County', 1.0),
#  ('Nuckolls County', 1.0),
#  ('Comanche County', 1.0),
#  ('Orangeburg County', 1.0),
#  ('McCracken County', 1.0),
#  ('Sac County', 1.0),
#  ('Randolph County', 1.0),
#  ('Bay County', 1.0),
#  ('Paulding County', 1.0),
#  ('Crittenden County', 1.0),
#  ('Van Zandt County', 1.0),
#  ('Dougherty County', 1.0),
#  ('San Juan County', 1.0),
#  ('Stephenson County', 1.0),
#  ('Harvey County', 1.0),
#  ('Laurens County', 1.0),
#  ('Beaufort County', 1.0),
#  ('Elbert County', 1.0),
#  ('Grand Forks County', 1.0),
#  ('Livingston Parish', 1.0),
#  ('Weld County', 1.0),
#  ('Grayson County', 1.0),
#  ('Green County', 1.0),
#  ('Harrison County', 1.0),
#  ('Sedgwick County', 1.0),
#  ('Sumner County', 1.0),
#  ('Dutchess County', 1.0),
#  ('Randall County', 1.0),
#  ('Clackamas County', 1.0),
#  ('Hawaii County', 1.0),
#  ('Sumter County', 1.0),
#  ('Suffolk city', 1.0),
#  ('Kenai Peninsula Borough', 1.0),
#  ('Chatham County', 1.0),
#  ('Carroll County', 1.0),
#  ('Caldwell County', 1.0),
#  ('Horry County', 1.0),
#  ('Doa Ana County', 1.0),
#  ('Winona County', 1.0),
#  ('San Bernardino County', 1.0),
#  ('Highlands County', 1.0),
#  ('Hocking County', 1.0),
#  ('Bond County', 1.0),
#  ('Orleans Parish', 1.0),
#  ('Person County', 1.0),
#  ('Hardin County', 1.0),
#  ('Weber County', 1.0),
#  ('Guthrie County', 1.0),
#  ('Fayette County', 1.0),
#  ('Montcalm County', 1.0),
#  ('Coryell County', 1.0),
#  ('Ulster County', 1.0),
#  ('Hall County', 1.0),
#  ('Yellowstone County', 1.0),
#  ('St. Lawrence County', 1.0),
#  ('Galveston County', 1.0),
#  ('Henderson County', 1.0),
#  ('Georgetown County', 1.0),
#  ('Indiana County', 1.0),
#  ('Riley County', 1.0),
#  ('Calaveras County', 1.0),
#  ('Kendall County', 1.0),
#  ('Waupaca County', 1.0),
#  ('Bristol County', 1.0),
#  ('Sutter County', 1.0),
#  ('Pottawattamie County', 1.0),
#  ('Pulaski County', 1.0),
#  ('Emmet County', 1.0),
#  ('', 1.0),
#  ('Woodruff County', 1.0),
#  ('Anson County', 1.0),
#  ('Pennington County', 1.0),
#  ('Wilson County', 1.0),
#  ('Lewis County', 1.0),
#  ('Nevada County', 1.0),
#  ('Hampton city', 1.0),
#  ('Jackson Parish', 1.0),
#  ('Mercer County', 1.0),
#  ('Berkshire County', 1.0),
#  ('Santa Rosa County', 1.0),
#  ('Taos County', 1.0),
#  ('Rock County', 1.0),
#  ('Dodge County', 1.0),
#  ('Sauk County', 1.0),
#  ('Stearns County', 1.0),
#  ('Whatcom County', 1.0),
#  ('Haywood County', 1.0),
#  ('Gladwin County', 1.0),
#  ('Fannin County', 1.0),
#  ('Providence County', 1.0),
#  ('Blount County', 1.0),
#  ('Rooks County', 1.0),
#  ('Wise County', 1.0),
#  ('Ellis County', 1.0),
#  ('Kosciusko County', 1.0),
#  ('Skagit County', 1.0),
#  ('Lyon County', 1.0),
#  ('Ross County', 1.0),
#  ('Clermont County', 1.0),
#  ('Park County', 1.0),
#  ('Oneida County', 1.0),
#  ('St. Lucie County', 1.0),
#  ('Somerset County', 1.0),
#  ('Williams County', 1.0),
#  ('Payette County', 1.0),
#  ('Routt County', 1.0),
#  ('Potter County', 1.0),
#  ('Muskegon County', 1.0),
#  ('Muskogee County', 1.0),
#  ('Decatur County', 1.0),
#  ('Muskingum County', 1.0),
#  ('Walla Walla County', 1.0),
#  ('Cambria County', 1.0),
#  ('Presque Isle County', 1.0),
#  ('Dorchester County', 1.0),
#  ('Malheur County', 1.0),
#  ('Ingham County', 1.0),
#  ('Kenosha County', 1.0),
#  ('Dyer County', 1.0),
#  ('Grand County', 1.0),
#  ('Hendry County', 1.0),
#  ('Rutherford County', 1.0),
#  ('Cochise County', 1.0),
#  ('Anderson County', 1.0),
#  ('Shawnee County', 1.0),
#  ('Merrimack County', 1.0),
#  ('Maui County', 1.0),
#  ('Lynchburg city', 1.0),
#  ('Spalding County', 1.0),
#  ('Yavapai County', 1.0),
#  ('Klamath County', 1.0),
#  ('Houston County', 1.0),
#  ('Morgan County', 1.0),
#  ('Craig County', 1.0),
#  ('Gwinnett County', 1.0),
#  ('Latah County', 1.0),
#  ('Napa County', 1.0),
#  ('Virginia Beach city', 1.0),
#  ('Larue County', 1.0),
#  ('Sagadahoc County', 1.0),
#  ('Grafton County', 1.0),
#  ('Amherst County', 1.0),
#  ('Alpena County', 1.0),
#  ('Sullivan County', 1.0),
#  ('Colquitt County', 1.0),
#  ('Lincoln County', 1.0),
#  ('Le Sueur County', 1.0),
#  ('Waldo County', 1.0),
#  ('Herkimer County', 1.0),
#  ('Forsyth County', 1.0),
#  ('Midland County', 1.0),
#  ('Beaver County', 1.0),
#  ('Clayton County', 1.0),
#  ('Erath County', 1.0),
#  ('Casey County', 1.0),
#  ('Teller County', 1.0),
#  ('Bingham County', 1.0),
#  ('Champaign County', 1.0),
#  ('Hampshire County', 1.0),
#  ('Amador County', 1.0),
#  ('Pecos County', 1.0),
#  ('Izard County', 1.0),
#  ('Luce County', 1.0),
#  ('Dawson County', 1.0),
#  ('Kane County', 1.0),
#  ('Meeker County', 1.0),
#  ('McIntosh County', 1.0),
#  ('Eaton County', 1.0),
#  ('Bartholomew County', 1.0),
#  ('Windsor County', 1.0),
#  ('Barnwell County', 1.0),
#  ('Rowan County', 1.0),
#  ('Rankin County', 1.0),
#  ('Muscatine County', 1.0),
#  ('Taney County', 1.0),
#  ('Buchanan County', 1.0),
#  ('Oconee County', 1.0),
#  ('Outagamie County', 1.0),
#  ('Lebanon County', 1.0),
#  ('Northampton County', 1.0),
#  ('Martin County', 1.0),
#  ('Coos County', 1.0),
#  ('Halifax County', 1.0),
#  ('Bartow County', 1.0),
#  ('Rensselaer County', 1.0),
#  ('Grant Parish', 1.0),
#  ('Muscogee County', 1.0),
#  ('Holmes County', 1.0),
#  ('St. Johns County', 0.9833333333333333),
#  ('Plymouth County', 0.9827586206896551),
#  ('McLennan County', 0.9818181818181818),
#  ('Lorain County', 0.9814814814814815),
#  ('Chesterfield County', 0.9782608695652174),
#  ('Putnam County', 0.9772727272727273),
#  ('Alexandria city', 0.9767441860465116),
#  ('Thurston County', 0.975609756097561),
#  ('Gloucester County', 0.975),
#  ('New Castle County', 0.975),
#  ('Chester County', 0.9722222222222222),
#  ('Cass County', 0.9722222222222222),
#  ('Windham County', 0.9714285714285714),
#  ('Benton County', 0.9714285714285714),
#  ('Elkhart County', 0.9696969696969697),
#  ('Schenectady County', 0.9696969696969697),
#  ('Frederick County', 0.9666666666666667),
#  ('Tioga County', 0.9629629629629629),
#  ('Pierce County', 0.9615384615384616),
#  ('Stark County', 0.96),
#  ('Rockland County', 0.9565217391304348),
#  ('Mobile County', 0.9545454545454546),
#  ('Nelson County', 0.9523809523809523),
#  ('Shasta County', 0.95),
#  ('Marion County', 0.9473684210526315),
#  ('Ada County', 0.9473684210526315),
#  ('Clearfield County', 0.9473684210526315),
#  ('Onondaga County', 0.9444444444444444),
#  ('McMinn County', 0.9411764705882353),
#  ('Niagara County', 0.9411764705882353),
#  ('San Joaquin County', 0.9411764705882353),
#  ('Peoria County', 0.9411764705882353),
#  ('El Dorado County', 0.9333333333333333),
#  ('Taylor County', 0.9285714285714286),
#  ('Sussex County', 0.9230769230769231),
#  ('Luzerne County', 0.9230769230769231),
#  ('Fresno County', 0.9166666666666666),
#  ('Arlington County', 0.9166666666666666),
#  ('Richmond County', 0.9166666666666666),
#  ('Clay County', 0.9090909090909091),
#  ('Guilford County', 0.9090909090909091),
#  ('Cocke County', 0.9090909090909091),
#  ('Iredell County', 0.9),
#  ('Citrus County', 0.9),
#  ('Kern County', 0.8888888888888888),
#  ('Lackawanna County', 0.8888888888888888),
#  ('Bonneville County', 0.875),
#  ('Belknap County', 0.875),
#  ('Oswego County', 0.875),
#  ('Butte County', 0.875),
#  ('Passaic County', 0.8571428571428571),
#  ('Ashtabula County', 0.8333333333333334),
#  ('Kent County', 0.8333333333333334),
#  ('Milwaukee County', 0.8333333333333334),
#  ('Norfolk city', 0.8333333333333334),
#  ('Dubuque County', 0.8),
#  ('Morris County', 0.8),
#  ('Forrest County', 0.8),
#  ('Tuscaloosa County', 0.8),
#  ('Wythe County', 0.8),
#  ('Oklahoma County', 0.75),
#  ('Rockingham County', 0.6666666666666666),
#  ('Lexington County', 0.6666666666666666),
#  ('Knox County', 0.6666666666666666),
#  ('Wyandotte County', 0.6666666666666666),
#  ('Berkeley County', 0.6666666666666666),
#  ('Portage County', 0.5),
#  ('Racine County', 0.5),
#  ('Pasco County', 0.5),
#  ('Ottawa County', 0.5),
#  ('Natrona County', 0.5),
#  ('Pontotoc County', 0.5),
#  ('Schuylkill County', 0.5),
#  ('East Baton Rouge Parish', 0.5),
#  ('Monongalia County', 0.5),
#  ('Lafayette Parish', 0.5),
#  ('Henrico County', 0.5),
#  ('Clarke County', 0.5),
#  ('St. Tammany Parish', 0.5),
#  ('Will County', 0.5),
#  ('St. Joseph County', 0.0),
#  ('Eau Claire County', 0.0),
#  ('Genesee County', 0.0),
#  ('Smith County', 0.0),
#  ('Carbon County', 0.0),
#  ('Edgecombe County', 0.0),
#  ('Wabash County', 0.0),
#  ('Fauquier County', 0.0),
#  ('Peach County', 0.0),
#  ('Moore County', 0.0),
#  ('Island County', 0.0),
#  ('Indian River County', 0.0),
#  ('Bergen County', 0.0),
#  ('Bibb County', 0.0),
#  ('Falls Church city', 0.0),
#  ('Olmsted County', 0.0),
#  ('Yuma County', 0.0),
#  ('Ripley County', 0.0),
#  ('Bon Homme County', 0.0),
#  ('San Jacinto County', 0.0),
#  ('Pueblo County', 0.0),
#  ('Okaloosa County', 0.0),
#  ('Susquehanna County', 0.0),
#  ('Mesa County', 0.0),
#  ('Nueces County', 0.0),
#  ('Broome County', 0.0),
#  ('Webster County', 0.0),
#  ('Daviess County', 0.0),
#  ('Kershaw County', 0.0),
#  ('Brown County', 0.0),
#  ('Schuyler County', 0.0),
#  ('Rockcastle County', 0.0),
#  ('Tooele County', 0.0),
#  ('Humboldt County', 0.0),
#  ('Bulloch County', 0.0),
#  ('Alachua County', 0.0),
#  ('Gallia County', 0.0),
#  ('Becker County', 0.0),
#  ('Iberia Parish', 0.0),
#  ('Elko County', 0.0),
#  ('Leon County', 0.0),
#  ('Marshall County', 0.0),
#  ('Cleveland County', 0.0),
#  ('Rapides Parish', 0.0),
#  ('Roane County', 0.0),
#  ('Trumbull County', 0.0),
#  ('Sheboygan County', 0.0),
#  ('Yuba County', 0.0),
#  ('Roanoke city', 0.0),
#  ('Dakota County', 0.0),
#  ('Vermillion County', 0.0),
#  ('Tuscarawas County', 0.0),
#  ('Lubbock County', 0.0),
#  ('Tyler County', 0.0),
#  ('White County', 0.0),
#  ('Caledonia County', 0.0),
#  ('Androscoggin County', 0.0),
#  ('Hancock County', 0.0),
#  ('De Soto Parish', 0.0),
#  ('Raleigh County', 0.0),
#  ('Harford County', 0.0),
#  ('Brazos County', 0.0),
#  ('Terrebonne Parish', 0.0),
#  ('Chautauqua County', 0.0),
#  ('Salem city', 0.0),
#  ('Cheshire County', 0.0),
#  ('Acadia Parish', 0.0),
#  ('McCurtain County', 0.0),
#  ('Yancey County', 0.0),
#  ('Seneca County', 0.0),
#  ('Hale County', 0.0),
#  ('Trigg County', 0.0),
#  ('Davis County', 0.0),
#  ('Crisp County', 0.0),
#  ('Bethel Census Area', 0.0),
#  ('Woodbury County', 0.0),
#  ('Portsmouth city', 0.0),
#  ('Hernando County', 0.0),
#  ('Barry County', 0.0),
#  ('Shiawassee County', 0.0),
#  ('Ben Hill County', 0.0),
#  ('Allegan County', 0.0),
#  ('Wyoming County', 0.0),
#  ('Walker County', 0.0),
#  ('Christian County', 0.0),
#  ('Comal County', 0.0),
#  ('Cameron County', 0.0)]
